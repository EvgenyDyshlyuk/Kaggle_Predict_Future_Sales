# %% [markdown]
# # 3. HPO (hyperparameters optimization)
# Baysian optimization is used to evaluate best hyperparameters for different models. Baysian - roughly means that all hyperparameters are indipendent of each other (this is not exactly true, but is often a good, working, and robust approximaton). Baysian optimization works better than random and grid search for expensive computations, because additional cost for calculation of better hyperparameters optimization space is negligable. Otherwize (if the calculation of the main function is inexpensive), it is better to use Randon search or even Grid search. Good descriptions and examples can be found here: https://colab.research.google.com/github/lmassaron/kaggledays-2019-gbdt/blob/master/Kaggle%20Days%20Paris%20-%20%20GBDT%20workshop.ipynb.
#
# ### Different libraries exist for HPO:
# - Scikit-Optimize
# - Hyperopt
# - Optuna
# - hpbandster
# - BayesianOptimization
# - Sherpa
# - SMAC3
#
# Scikit-Optimize (https://github.com/scikit-optimize/scikit-optimize) is used here, thanks to this review comparison: (https://towardsdatascience.com/hyperparameter-optimization-in-python-part-0-introduction-c4b66791614b), where Scikit-Optimize wins against Hyperopt:
# - Scikit-Optimize (https://towardsdatascience.com/hyperparameter-optimization-in-python-part-1-scikit-optimize-754e485d24fe)
# - Hyperopt        (https://towardsdatascience.com/hyperparameter-optimization-in-python-part-2-hyperopt-5f661db91324)
#
# ### Different optimizers can be used by Bayesian optimization (https://scikit-optimize.github.io/#skopt.dump):
# - dummy_minimize - which is a random search - just for comparison
# - gp_minimize: Gaussian Process optimizer works best on gaussian-like parameters with a (not-very-big) parameters space.
# - gbrt_mininize: Tree-based process - works best on high-dimensionality space, especially, if the parameters belong to different types, e.g. one parameter is integer, second is float, third is categorical, etc. (https://www.youtube.com/watch?v=DGJTEBt0d-s from 21:00). This is often the case, when we do not know very well our models and try very different parameters to tune for better performance.
# - forest_minimize: Sequential optimisation using decision trees.
#
# Good example and description can be found here: https://neptune.ml/blog/scikit-optimize. In this example forest_minimize showed better results than gp or gbrt.
# Good description of the parameters is avalible here: https://721-54340642-gh.circle-artifacts.com/0/tmp/circle-artifacts.kdXLWjd/api/minimize_functions.html

# %%
# %reset -f  #reset magic function allows one to release all previously used memory. -f (force) parameter allows to run it without confirmation from the user

# %run libraries_and_functions
# Out:
# Don't know how to reset  #reset, please run `%reset?` for details
# Don't know how to reset  magic, please run `%reset?` for details
# Don't know how to reset  function, please run `%reset?` for details
# Don't know how to reset  allows, please run `%reset?` for details
# Don't know how to reset  one, please run `%reset?` for details
# Don't know how to reset  to, please run `%reset?` for details
# Don't know how to reset  release, please run `%reset?` for details
# Don't know how to reset  all, please run `%reset?` for details
# Don't know how to reset  previously, please run `%reset?` for details
# Don't know how to reset  used, please run `%reset?` for details
# Don't know how to reset  memory., please run `%reset?` for details
# Don't know how to reset  -f, please run `%reset?` for details
# Don't know how to reset  (force), please run `%reset?` for details
# Don't know how to reset  parameter, please run `%reset?` for details
# Don't know how to reset  allows, please run `%reset?` for details
# Don't know how to reset  to, please run `%reset?` for details
# Don't know how to reset  run, please run `%reset?` for details
# Don't know how to reset  it, please run `%reset?` for details
# Don't know how to reset  without, please run `%reset?` for details
# Don't know how to reset  confirmation, please run `%reset?` for details
# Don't know how to reset  from, please run `%reset?` for details
# Don't know how to reset  the, please run `%reset?` for details
# Don't know how to reset  user, please run `%reset?` for details
# Libraries and functions loaded

# %%
# Load data
X = pd.read_pickle(r'output/data/X_2.6_Final.pkl')

X_train = X[X.date_block_num < 33].drop(['item_cnt_month'], axis=1)
y_train = X[X.date_block_num < 33]['item_cnt_month']
X_val = X[X.date_block_num == 33].drop(['item_cnt_month'], axis=1)
y_val = X[X.date_block_num == 33]['item_cnt_month']
X_test = X[X.date_block_num == 34].drop(['item_cnt_month'], axis=1)

test = pd.read_csv('input/test.csv.gz') # used for submission

# %%
#Imort SKOPT 
import skopt

from skopt.space import Real, Integer

from skopt.utils import use_named_args

from skopt import gbrt_minimize, forest_minimize, gp_minimize

from skopt import dump, load

from skopt.plots import plot_convergence, plot_evaluations, plot_objective

from skopt.callbacks import CheckpointSaver, VerboseCallback # allows to save results for minimization function at each iteration (so do not loose if interrupted), Verbose is used to print verbosity - monitor progress

checkpoint_callback = CheckpointSaver(r'output/HPO_minimization_checkpoint_result.pkl') # Save current results at each iteration - will be used if run will not finish sucsessfully
verbose_callback = VerboseCallback(n_total=0) #starting point for the callback counter n_total

#Load the results from either last sucsessfully completed run or from checkpoint if the run was not finished successfully (e.g. was interrupted due to lack of time)
#res = load("./checkpoint_result.pkl")
#Get the starting point from load results: 
#initial_params_list = res.x
#Or simply set initial point by hand, e.g.: initial_params_list=[2401,6,83]
# Out:
# Iteration No: 1 started. Searching for the next optimal point.
# C:\Users\edyshlyu\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\externals\joblib\__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)

# %% [markdown]
# ## LGBM Optimization

# %% [markdown]
# LightGBM parameters tuning guide: https://lightgbm.readthedocs.io/en/latest/Parameters-Tuning.html

# %% [markdown]
# ### 1. Set for high speed because we want to try many variants:
# - That's not my case, but if you are a pro, you'll probably do it parallel https://lightgbm.readthedocs.io/en/latest/Parallel-Learning-Guide.html, use gpu https://lightgbm.readthedocs.io/en/latest/GPU-Tutorial.html, etc..
# - 'boosting' = 'gbdt' ('dart' is slower, 'goss' is even faster but was noticed to have convergence issues https://www.kaggle.com/c/home-credit-default-risk/discussion/60921)
# - 'num_threads' = 8 = number of threads on my small laptop (4-core). (Although it is suggested to set it to number of physical cores (https://lightgbm.readthedocs.io/en/latest/Parameters.html) = 4 in my case), it works faster for me setting it to number of threads = 8. Deafault = 0 sets it according to OpenMP to 4, which is slower in my case. This approach for small computers is also proved in here https://www.kaggle.com/c/microsoft-malware-prediction/discussion/79131. For big computers with good number of cores the situation is different: see the answer in this discussion: https://www.kaggle.com/c/microsoft-malware-prediction/discussion/79131 e.g. "do not set it too large if your dataset is small (for instance, do not use 64 threads for a dataset with 10,000 rows). Be aware a task manager or any similar CPU monitoring tool might report that cores not being fully utilized. This is normal. or parallel learning, do not use all CPU cores because this will cause poor performance for the network communication"
# - 'save_binary'=True (will save the data set(include validation data) to a binary file. Speed up the data loading speed for the next time)
# - 'bagging fraction' = [0,1] set to smaller value (depending on the set size, so that it is still representative).
# - 'bagging_freq' = [1,k] - perform bagging each k-th operation (the bigger the faster it is, set to e.g.: 5)
# - 'feature fraction' = [0,1] set to smaller value, depending on number of features. E.g. use 0.5
#
# optimize for:
# - num_leaves
# - max_depth
# - min_data_in_leaf
# - max_bin
#
# ### 2. Increase 'num_boost_round', decrease 'learning_rate'
# ### 3. Try 'dart' boosting to improve accuracy
# (dart is significantly: e.g. 2 times slower than gbdt but often shows better accuracy). 'goss' type is fastest but prone to convergence issues:
#
# https://github.com/Microsoft/LightGBM/issues/695
#
# https://github.com/lmassaron/kaggledays-2019-gbdt/blob/master/Kaggle%20Days%20Paris%20-%20Skopt%20%2B%20CatBoost%20solution.ipynb

# %%
import lightgbm as lgb

# Prepare the data for LGBM
lgb_train_data = lgb.Dataset(X_train, label=y_train)
lgb_val_data = lgb.Dataset(X_val, label=y_val)

# %%
# Define the lgb search space (dynamic parameters)
search_space  = [Integer(127, 16383, name='num_leaves'), # Real(0.00001, 0.1, prior = "log-uniform", name = 'learning_rate') #points are sampled uniformly between log10(lower) and log10(upper)
                 Integer(2, 31, name='max_depth'),
                 Integer(63, 4095, name='min_data_in_leaf'),
                 Integer(63, 4095, name='max_bin')]

learning_rate = 0.01 # initialize learning_rate

# Define lgb static parameters
static_params = {'objective': 'regression',
                 'metric':'rmse',      
                 'boosting': 'gbdt',
                 'num_threads': 8, 
                 'learning_rate': learning_rate,
                 'bagging_fraction': 0.5, #[0,1] speed up training and reduce overfitting - fraction of data to use
                 'bagging_freq': 1, #[0,k] perform baging each k-th iteration
                 'bagging_seed': 42,
                 'feature_fraction': 0.5, #Feature sub-sampling
                 'save_binary': True} #   

# Define lgb train parameters
num_boost_round = 500
early_stopping_rounds = 10

# %%
# Define a function to minimize - the function should return the value to minimize by gp_minimize function
@skopt.utils.use_named_args(search_space) # This decorator ( @ ) allows the objective function to receive the parameters as keyword arguments
def objective(**dynamic_params):

    params = {**dynamic_params, **static_params} # merge the two dictionaries
 
    model  = lgb.train(params,
                       lgb_train_dataset,
                       valid_sets=[lgb_train_dataset, lgb_val_dataset],
                       valid_names=['train','val'],
                       num_boost_round=num_boost_round,
                       early_stopping_rounds=early_stopping_rounds,
                       verbose_eval=None) # = 500 = show progress each 500 rounds

    rmse_train=model.best_score['train']['rmse']
    rmse_val=model.best_score['val']['rmse']
  
    print(dynamic_params, 'rmse_train=', round(rmse_train,4), 'rmse_val=', round(rmse_val,4))
  
    return rmse_val

# %% [raw]
# %%time
# # Let us see how different minimization functions work:
# initial_params_list=[1024, 12, 100, 1024] #initial_params_list=None # initial startint point for skopt search_space
# # number of function calls by skopt. minimum value for n_call = random_starts (default = 10 - this is how many times search is done randomly before evaluation of optimized space) +  1 (if inital params list is set)
#
# %time res_gbrt = gbrt_minimize(objective, search_space, n_calls=100, x0=initial_params_list, callback=[checkpoint_callback], random_state=42)
# print('Best score for gbrt_minimize', 'rmse_val=', res_gbrt.fun, 'Best parameters:', res_gbrt.x)
# dump(res_gbrt, r'output/HPO_minimization_gbrt_result.pkl')
#
# %time res_gp = gp_minimize(objective, search_space, n_calls=100, x0=initial_params_list, callback=[checkpoint_callback], random_state=42)
# print('Best score for gp_minimize', 'rmse_val=', res_gp.fun, 'Best parameters:', res_gp.x)
# dump(res_gp, r'output/HPO_minimization_gp_result.pkl')
#
# %time res_forest = forest_minimize(objective, search_space, n_calls=100, x0=initial_params_list, callback=[checkpoint_callback], random_state=42)
# print('Best score for forest_minimize', 'rmse_val=', res_forest.fun, 'Best parameters:', res_forest.x)
# dump(res_forest, r'output/HPO_minimization_forest_result.pkl')

# %% [raw]
# For
# search_space  = [Integer(7, 16383, name='num_leaves'), # Real(0.00001, 0.1, prior = "log-uniform", name = 'learning_rate') #points are sampled uniformly between log10(lower) and log10(upper)
#                  Integer(2, 63, name='max_depth'),
#                  Integer(63, 511, name='min_data_in_leaf'),
#                  Integer(63, 4095, name='max_bin')]
#
# learing_rate = 0.01,
# num_boost_round=500,
# early_stopping_rounds=10,
#
# n_call = 100
#
# The obtained results are:
#
# Wall time: 8h 54min 45s
# Best score for gbrt_minimize rmse_val= 0.804709587191561 Best parameters: [12267, 24, 508, 3882]
#
# Wall time: 10h 47min 33s
# Best score for gp_minimize rmse_val= 0.8046892127047138 Best parameters: [802, 29, 508, 2813]
#
# Wall time: 5h 47min 36s
# Best score for forest_minimize rmse_val= 0.8042525384529841 Best parameters: [4367, 10, 498, 945]

# %%
#  Now plot the results
res_gbrt = load( r'output/HPO_minimization_gbrt_result.pkl')
res_gp = load( r'output/HPO_minimization_gp_result.pkl')
res_forest = load( r'output/HPO_minimization_forest_result.pkl')

results = [('gbrt_results', res_gbrt), ('gp_results', res_gp), ('forest_results', res_forest)] # put results together for plotting
plot_convergence(*results)
plt.show()

for res in (res_gbrt, res_gp, res_forest): # Plot pairwise search_space for minimization function      
    print('Best score:', 'rmse_val=', res.fun, 'Best parameters:', res.x)
    plot_objective(res) #plot_convergence(res) # Can also be shown, but plot_objective is more informative 
    plt.show()
    #plot_evaluations(res) - to plot progress
# Out:
# Best score: rmse_val= 0.804709587191561 Best parameters: [12267, 24, 508, 3882]
# Best score: rmse_val= 0.8046892127047138 Best parameters: [802, 29, 508, 2813]
# Best score: rmse_val= 0.8042525384529841 Best parameters: [4367, 10, 498, 945]

# %% [markdown]
# As we see, in this particular case, forest_minimize did the job much quicker and much more accuratly. Forest was also shown to outperform gp and gbrt in https://neptune.ml/blog/scikit-optimize.
# Somehow, the gp_minimize and gbrt were not able to find a minimum for max_depth (which is visible on all plots). Also, no visible dependence on max_bin is seen for gp and gbrt, while seen for forest.
# One can also notice that the learning is much more step-wize for forest, while gp and gbrt shows slower but constant progress...
#
# I guess, that for low number of n_calls (e.g. 100) forest_minimize might be a better strategy for byasian optimization, it is probable, that for high number of n_calls gbrt would on the opposite show better results....
# Forest is buid from strong learners - fully grown decision trees (low bias, high variance). It tackles the error reduction task by reducing variance. The trees are made uncorrelated to maximize the decrease in variance, but the algorithm cannot reduce bias (which is slightly higher than the bias of an individual tree in the forest). Hence the need for large, unpruned trees, so that the bias is initially as low as possible. The gbrt boosting is build from an ensemble week learners (high bias, low variance). Boosting reduces error mainly by reducing bias (and also to some extent variance, by aggregating the output from many models).

# %% [raw]
# For different random_starts parameter with forest_minimize:
# random_starts = 5
# Wall time: 5h 25min 19s
# Best score for forest_minimize_random5 rmse_val= 0.8040299343243771 Best parameters: [2052, 10, 473, 4019]
#
# n_random_starts = 10
# Wall time: 5h 47min 36s
# Best score for forest_minimize rmse_val= 0.8042525384529841 Best parameters: [4367, 10, 498, 945]
#
# n_random_starts = 15
# Wall time: 6h 22min 34s
# Best score for forest_minimize_random15 rmse_val= 0.8039103047008371 Best parameters: [3487, 10, 472, 437]
#
# n_random_starts = 5 (best score better than random_start = 10 by luck) seems to be to low - the plotted parameter graphs are not smooth. random_starts = 15 is obtaining better results but takes longer to converge. For n_call = 100, random_starts = 10 is probably safe, if more n_call is used, than more random_starts should probably be used.

# %% [raw]
# # Now let us refine search space and find the optimum
# search_space  = [Integer(255, 8191, name='num_leaves'), # Real(0.00001, 0.1, prior = "log-uniform", name = 'learning_rate') #points are sampled uniformly between log10(lower) and log10(upper)
#                  Integer(7, 15, name='max_depth'),
#                  Integer(63, 4095, name='min_data_in_leaf'),
#                  Integer(63, 4095, name='max_bin')]
#
#
# num_boost_round = 1000
# early_stopping_rounds = 10
# learning_rate = 0.01
#
# initial_params_list=[4367, 10, 498, 945]
# n_calls=500
#
# %time res = forest_minimize(objective, search_space, n_calls=n_calls, x0=initial_params_list, callback=[checkpoint_callback, verbose_callback], n_random_starts = 20, random_state=42)
# dump(res, r'output/HPO_LGBM_result.pkl')

# %%
res = load(r'output/HPO_LGBM_result.pkl')
print('Best params:', res.x)
plot_convergence(res)
plot_objective(res)
# Out:
# Best params: [1417, 10, 469, 97]
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001E1A3FEC518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E1A3FB23C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E1A3F7A208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E1A2F710B8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001E1A2F30EB8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E1A2EF7CF8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E1A2EBDB38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E1A2E859B0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001E1A2E4C320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E1A2E0BC88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E1A1E00518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E1A1DBFDA0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001E1A1D876D8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E1A1D44E80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E1A1D09828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E1A1CD20B8>]],
#       dtype=object)

# %% [raw]
# search_space  = [Integer(255, 8191, name='num_leaves'), # Real(0.00001, 0.1, prior = "log-uniform", name = 'learning_rate') #points are sampled uniformly between log10(lower) and log10(upper)
#                  Integer(7, 15, name='max_depth'),
#                  Integer(63, 4095, name='min_data_in_leaf'),
#                  Integer(63, 4095, name='max_bin')]
#
# num_boost_round = 1000
# early_stopping_rounds = 10
# learning_rate = 0.01
#
# initial_params_list=[4367, 10, 498, 945]
# n_calls=500
#
# Wall time: 1d 9h 50min 39s
# [1417, 10, 469, 97]
# Current minimum: 0.8027
# __________________________________________________________________________________________
# [1000] Best score=0.7842
# Best parameters:
# - learning_rate=0.007082
# - max_depth=20
# - num_leaves=961
# - max_bin=233
# Wall time: 1d 16min 46s

# %%
#Take the best found parameters
best_dynamic_params = dict(zip(['num_leaves', 'max_depth', 'min_data_in_leaf', 'max_bin'], res.x))
params = {**best_dynamic_params, **static_params}

# %%
params
# Out:
# {'num_leaves': 1417,
#  'max_depth': 10,
#  'min_data_in_leaf': 469,
#  'max_bin': 97,
#  'objective': 'regression',
#  'metric': 'rmse',
#  'boosting': 'gbdt',
#  'num_threads': 8,
#  'learning_rate': 0.01,
#  'bagging_fraction': 0.5,
#  'bagging_freq': 1,
#  'bagging_seed': 42,
#  'feature_fraction': 0.5,
#  'save_binary': True}

# %% [markdown]
# ## Now run best parameters with increased num_boost_rounds, decrease learning rate

# %%
# Define run LGBM function
def LGBM(num_boost_round, learning_rate, early_stopping_rounds, boosting):
    
    params['learning_rate'] = learning_rate
    params['boosting'] = boosting
    
    evals_result = {}  # to record eval results for plotting

    model = lgb.train(params,
                      lgb_train_data, 
                      num_boost_round=num_boost_round,
                      valid_sets=[lgb_train_data, lgb_val_data],
                      valid_names=['train','val'],
                      early_stopping_rounds=early_stopping_rounds,
                      evals_result=evals_result,                      
                      verbose_eval=500)
    
    y_pred_test = model.predict(X_test, num_iteration=model.best_iteration).clip(0,20) # Competition evaluation requirement: True target values are clipped into [0,20] range
    
    RMSE_train = evals_result['train']['rmse']
    RMSE_val = evals_result['val']['rmse'] 
      
#________________________________________________________________________________________
# Plotting results
    plt.plot(evals_result['train']['rmse'], 'g', label='train')
    plt.plot(evals_result['val']['rmse'], 'r', label='val')
    plt.legend(loc = 'upper right')
    plt.grid(True)
    plt.show()
  
    return y_pred_test, RMSE_train, RMSE_val

# %%
# %%time
y_pred_test, RMSE_train, RMSE_val = LGBM(num_boost_round = 10000, learning_rate  = 0.001, early_stopping_rounds = 100, boosting = 'gbdt')

# %%
submission = pd.DataFrame({'ID': test.index, 'item_cnt_month': y_pred_test})
submission.to_csv(r'output/lgbm_HPO_submission.csv', index=False)

# %%
LB score: 0.90742

# %%
# %%time
# Let us check how the result will change if we use all features and no bagging
params['bagging_fraction'] = 1
params['feature_fraction'] = 1

y_pred_test1, RMSE_train1, RMSE_val1 = LGBM(num_boost_round = 10000, learning_rate  = 0.001, early_stopping_rounds = 100, boosting = 'gbdt')
# Out:
# Training until validation scores don't improve for 100 rounds
# [500]	train's rmse: 0.985737	val's rmse: 0.918942
# [1000]	train's rmse: 0.89325	val's rmse: 0.851178
# [1500]	train's rmse: 0.849943	val's rmse: 0.825918
# [2000]	train's rmse: 0.827254	val's rmse: 0.815067
# [2500]	train's rmse: 0.813744	val's rmse: 0.810358
# [3000]	train's rmse: 0.803942	val's rmse: 0.807513
# Early stopping, best iteration is:
# [3140]	train's rmse: 0.801815	val's rmse: 0.807246
# Wall time: 49min 29s

# %% [markdown]
# ## Now try 'dart' boosting
#
# %time LGBM(num_boost_round = 1000, learning_rate  = 0.01, early_stopping_rounds = 10, boosting = 'gbdt')
#
# %time LGBM(num_boost_round = 1000, learning_rate  = 0.01, early_stopping_rounds = 10, boosting = 'dart')
#
# Dart boosting did a worse job (for lower learning rate as well), its learing curve is irregular, and it is so much more slower - tens of  times!  Use gbdt.

# %% [markdown]
# ### XGB

# %%
from xgboost import XGBRegressor

from sklearn.metrics import mean_squared_error

# %%
# Define the CatBoost search space (dynamic parameters)
search_space_xgb  = [Integer(6, 12, name='max_depth'),
                     Integer(0, 1000, name='min_child_weight'),
                     Real(0, 100, name='gamma'),
                     Real(0, 1, name='colsample_bytree')]

static_params_xgb = {'learning_rate': 0.2,
                     'n_estimators': 100,
                     'subsample': 0.5,
                     'objective': 'reg:squarederror',
                     'tree_method': 'approx',
                     'n_jobs': 8,
                     'random_state': 42}

# %%
# Define a function to minimize - the function should return the value to minimize by gp_minimize function
@skopt.utils.use_named_args(search_space_xgb) # This decorator ( @ ) allows the objective function to receive the parameters as keyword arguments
def objective(**dynamic_params_xgb): # n_call is used to monitor minimization progress
    
    print('Solving for:', dynamic_params_xgb)
 
    model =  XGBRegressor(**static_params_xgb, **dynamic_params_xgb)

    model.fit(X_train, y_train,
              eval_set=[(X_train, y_train), (X_val, y_val)],
              verbose = False,
              early_stopping_rounds = 5)        
     
    y_pred_val = model.predict(X_val).clip(0,20)
    rmse_val = np.sqrt(mean_squared_error(y_pred_val, y_val))

    return rmse_val

# %%
# %%time
res_xgb = forest_minimize(objective, search_space, n_calls=100, x0=None, callback=[checkpoint_callback], random_state=42)
dump(res_xgb, r'output/HPO_xgb_minimization_result.pkl')

#xgb_params['learing_rate'] = 0.01
#rmse_val= 0.8058033 Best parameters: [10, 0, 4.311568830991819, 0.24198586492878643]

# %%
res_xgb = load(r'output/HPO_xgb_minimization_result.pkl')
print('rmse_val=', res_xgb.fun, 'Best parameters:', res_xgb.x)
plot_convergence(res_xgb)
plot_objective(res_xgb)
plt.show()
# Out:
# rmse_val= 0.8058033 Best parameters: [10, 0, 4.311568830991819, 0.24198586492878643]

# %%
# Take the best found parameters for xgb
dynamic_params_best_xgb = dict(zip(['max_depth', 'min_child_weight', 'gamma', 'colsample_bytree'], res_xgb.x))
xgb_params = {**dynamic_params_best_xgb, **static_params_xgb}

# %%
# %%time
#Now decrease the learning_rate=0.01 and use bigger early_stopping=10 to find the optimum
xgb_params['learning_rate'] = 0.01
xgb_params['n_estimators'] = 1000
print(xgb_params)

model =  XGBRegressor(**xgb_params)

model.fit(X_train, y_train,
          eval_set=[(X_train, y_train), (X_val, y_val)],
          verbose = 100,
          early_stopping_rounds = 20)        
     
y_pred_val_xgb = model.predict(X_val).clip(0,20)
rmse_val_xgb = np.sqrt(mean_squared_error(y_pred_val, y_val))
print('RMSE_val_xgb:', rmse_val_xgb)
# Out:
# {'max_depth': 10, 'min_child_weight': 0, 'gamma': 4.311568830991819, 'colsample_bytree': 0.24198586492878643, 'learning_rate': 0.01, 'n_estimators': 1000, 'subsample': 0.5, 'objective': 'reg:squarederror', 'tree_method': 'approx', 'n_jobs': 8, 'random_state': 42}
# [0]	validation_0-rmse:1.20178	validation_1-rmse:1.10215
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 20 rounds.
# [100]	validation_0-rmse:0.938198	validation_1-rmse:0.886194
# [200]	validation_0-rmse:0.851891	validation_1-rmse:0.827448
# [300]	validation_0-rmse:0.81722	validation_1-rmse:0.810555
# [400]	validation_0-rmse:0.798442	validation_1-rmse:0.806591
# Stopping. Best iteration:
# [474]	validation_0-rmse:0.787393	validation_1-rmse:0.804435
#
# RMSE_val_xgb: 0.8058033
# Wall time: 1h 4min 26s

# %%
y_pred_test_xgb = model.predict(X_test).clip(0,20)

pickle.dump(model, open(r'output/xgb_model.pkl', 'wb')) #save best trained model

pickle.dump(y_pred_val_xgb, open(r'3. HPO/xgb_val.pkl', 'wb')) #save val_predictions
pickle.dump(y_pred_test_xgb, open(r'3. HPO/xgb_test.pkl', 'wb')) # save test_predictions for ensemble

# %%
# Create submission file
submission = pd.DataFrame({'ID': test.index, 'item_cnt_month': y_pred_test})
submission.to_csv(r'output/xgb_HPO_submission.csv', index=False)

# %% [raw]
# [474]	validation_0-rmse:0.787393	validation_1-rmse:0.804435
# Wall time: 1h 4min 26s
# 0.92342

# %%
def rmse(y_true, y_pred):
    return np.sqrt(mean_squared_error(y_true, y_pred))

# Early stopping rounds = 5 to avoid very long run for XGB
def run_xgb(X_train, y_train, X_val, y_val, X_test):

    model = XGBRegressor(n_estimators=1000,
                         colsample_bytree=0.8,
                         subsample=0.8,
                         eta=0.3,
                         seed=42)
    model.fit(X_train,
              y_train,
              eval_metric="rmse",
              eval_set=[(X_train, y_train), (X_val, y_val)],
              verbose=True,
              early_stopping_rounds = 10)
    
    y_pred_train = model.predict(X_train).clip(0,20)
    y_pred_val = model.predict(X_val).clip(0,20)
    y_pred_test = model.predict(X_test).clip(0,20)

    print(f"XGB: RMSE train: {rmse(y_train, y_pred_train)} RMSE val: {rmse(y_val, y_pred_val)}")
    return y_pred_val, y_pred_test, model

# %%
# %%time
y_pred_val_xgb, y_pred_test_xgb, xgb_model = run_xgb(X_train, y_train, X_val, y_val, X_test)

pickle.dump(xgb_model, open(r'output/xgb_model.pkl', 'wb')) # Save trained model to file
#pickle.dump(y_pred_val_xgb, open(r'3. HPO/xgb_val.pkl', 'wb')) # save predictions for an ensemble
#pickle.dump(y_pred_test_xgb, open(r'3. HPO/xgb_test.pkl', 'wb')) # save predictions for an ensemble

submission = pd.DataFrame({'ID': test.index, 'item_cnt_month': y_pred_test_xgb})
submission.to_csv(r'output/xgb_submission.csv', index=False)
# Out:
# C:\Users\edyshlyu\AppData\Local\Continuum\anaconda3\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# C:\Users\edyshlyu\AppData\Local\Continuum\anaconda3\lib\site-packages\xgboost\core.py:588: FutureWarning: Series.base is deprecated and will be removed in a future version
#   data.base is not None and isinstance(data, np.ndarray) \
# [14:00:27] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [14:00:27] WARNING: C:\Jenkins\workspace\xgboost-win64_release_0.90\src\learner.cc:686: Tree method is automatically selected to be 'approx' for faster speed. To use old behavior (exact greedy algorithm on single machine), set tree_method to 'exact'.
# [0]	validation_0-rmse:1.13502	validation_1-rmse:1.07032
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 10 rounds.
# [1]	validation_0-rmse:1.09959	validation_1-rmse:1.04007
# [2]	validation_0-rmse:1.07675	validation_1-rmse:1.0141
# [3]	validation_0-rmse:1.05546	validation_1-rmse:0.993451
# [4]	validation_0-rmse:1.01675	validation_1-rmse:0.975909
# [5]	validation_0-rmse:1.00134	validation_1-rmse:0.960171
# [6]	validation_0-rmse:0.987717	validation_1-rmse:0.947622
# [7]	validation_0-rmse:0.976719	validation_1-rmse:0.936343
# [8]	validation_0-rmse:0.966697	validation_1-rmse:0.928165
# [9]	validation_0-rmse:0.951019	validation_1-rmse:0.919783
# [10]	validation_0-rmse:0.943715	validation_1-rmse:0.912591
# [11]	validation_0-rmse:0.93735	validation_1-rmse:0.907344
# [12]	validation_0-rmse:0.932325	validation_1-rmse:0.902732
# [13]	validation_0-rmse:0.929102	validation_1-rmse:0.897539
# [14]	validation_0-rmse:0.925058	validation_1-rmse:0.894395
# [15]	validation_0-rmse:0.920333	validation_1-rmse:0.892212
# [16]	validation_0-rmse:0.917101	validation_1-rmse:0.889335
# [17]	validation_0-rmse:0.914236	validation_1-rmse:0.885925
# [18]	validation_0-rmse:0.911907	validation_1-rmse:0.883927
# [19]	validation_0-rmse:0.909954	validation_1-rmse:0.882248
# [20]	validation_0-rmse:0.907522	validation_1-rmse:0.88059
# [21]	validation_0-rmse:0.905925	validation_1-rmse:0.879644
# [69]	validation_0-rmse:0.874643	validation_1-rmse:0.85243
# [70]	validation_0-rmse:0.874464	validation_1-rmse:0.852396
# [71]	validation_0-rmse:0.874168	validation_1-rmse:0.851824
# [72]	validation_0-rmse:0.873987	validation_1-rmse:0.851719
# [73]	validation_0-rmse:0.873708	validation_1-rmse:0.851205
# [74]	validation_0-rmse:0.873334	validation_1-rmse:0.850387
# [75]	validation_0-rmse:0.87308	validation_1-rmse:0.850349
# [76]	validation_0-rmse:0.872758	validation_1-rmse:0.85016
# [77]	validation_0-rmse:0.872701	validation_1-rmse:0.850088
# [78]	validation_0-rmse:0.872531	validation_1-rmse:0.850117
# [79]	validation_0-rmse:0.872381	validation_1-rmse:0.85001
# [80]	validation_0-rmse:0.872149	validation_1-rmse:0.849974
# [81]	validation_0-rmse:0.871964	validation_1-rmse:0.849938
# [82]	validation_0-rmse:0.871827	validation_1-rmse:0.849923
# [83]	validation_0-rmse:0.871729	validation_1-rmse:0.849856
# [84]	validation_0-rmse:0.871523	validation_1-rmse:0.849873
# [85]	validation_0-rmse:0.871379	validation_1-rmse:0.849628
# [86]	validation_0-rmse:0.870774	validation_1-rmse:0.849164
# [87]	validation_0-rmse:0.870627	validation_1-rmse:0.849195
# [88]	validation_0-rmse:0.870341	validation_1-rmse:0.849002
# [89]	validation_0-rmse:0.869956	validation_1-rmse:0.848551
# [90]	validation_0-rmse:0.86976	validation_1-rmse:0.848587
# [91]	validation_0-rmse:0.869651	validation_1-rmse:0.848479
# [92]	validation_0-rmse:0.869526	validation_1-rmse:0.848793
# [93]	validation_0-rmse:0.86933	validation_1-rmse:0.84858
# [94]	validation_0-rmse:0.86925	validation_1-rmse:0.848437
# [95]	validation_0-rmse:0.869136	validation_1-rmse:0.848356
# [96]	validation_0-rmse:0.868645	validation_1-rmse:0.847284
# [97]	validation_0-rmse:0.868498	validation_1-rmse:0.847214
# [98]	validation_0-rmse:0.868319	validation_1-rmse:0.846965
# [99]	validation_0-rmse:0.867998	validation_1-rmse:0.846285
# [100]	validation_0-rmse:0.86795	validation_1-rmse:0.846262
# [101]	validation_0-rmse:0.867804	validation_1-rmse:0.846316
# [102]	validation_0-rmse:0.867667	validation_1-rmse:0.846432
# [103]	validation_0-rmse:0.866989	validation_1-rmse:0.846007
# [104]	validation_0-rmse:0.866846	validation_1-rmse:0.845899
# [105]	validation_0-rmse:0.865933	validation_1-rmse:0.844132
# [106]	validation_0-rmse:0.865594	validation_1-rmse:0.843534
# [107]	validation_0-rmse:0.864619	validation_1-rmse:0.842582
# [108]	validation_0-rmse:0.864441	validation_1-rmse:0.842348
# [109]	validation_0-rmse:0.864328	validation_1-rmse:0.842372
# [110]	validation_0-rmse:0.864233	validation_1-rmse:0.842415
# [111]	validation_0-rmse:0.86411	validation_1-rmse:0.842206
# [112]	validation_0-rmse:0.863149	validation_1-rmse:0.841315
# [113]	validation_0-rmse:0.863061	validation_1-rmse:0.841286
# [114]	validation_0-rmse:0.863004	validation_1-rmse:0.84124
# [115]	validation_0-rmse:0.862795	validation_1-rmse:0.841305
# [209]	validation_0-rmse:0.849739	validation_1-rmse:0.829424
# [210]	validation_0-rmse:0.849692	validation_1-rmse:0.82934
# [211]	validation_0-rmse:0.849635	validation_1-rmse:0.829357
# [212]	validation_0-rmse:0.849569	validation_1-rmse:0.829302
# [213]	validation_0-rmse:0.849507	validation_1-rmse:0.829157
# [214]	validation_0-rmse:0.849444	validation_1-rmse:0.829099
# [215]	validation_0-rmse:0.849397	validation_1-rmse:0.829137
# [216]	validation_0-rmse:0.849314	validation_1-rmse:0.829144
# [217]	validation_0-rmse:0.849254	validation_1-rmse:0.829187
# [218]	validation_0-rmse:0.849224	validation_1-rmse:0.829211
# [219]	validation_0-rmse:0.84915	validation_1-rmse:0.828873
# [220]	validation_0-rmse:0.849059	validation_1-rmse:0.8287
# [221]	validation_0-rmse:0.849029	validation_1-rmse:0.82866
# [222]	validation_0-rmse:0.848883	validation_1-rmse:0.828323
# [223]	validation_0-rmse:0.848604	validation_1-rmse:0.8279
# [224]	validation_0-rmse:0.848589	validation_1-rmse:0.827872
# [225]	validation_0-rmse:0.848524	validation_1-rmse:0.827823
# [226]	validation_0-rmse:0.848448	validation_1-rmse:0.827844
# [227]	validation_0-rmse:0.848383	validation_1-rmse:0.827889
# [228]	validation_0-rmse:0.848335	validation_1-rmse:0.827936
# [229]	validation_0-rmse:0.848272	validation_1-rmse:0.827859
# [230]	validation_0-rmse:0.848204	validation_1-rmse:0.827777
# [231]	validation_0-rmse:0.848074	validation_1-rmse:0.827566
# [232]	validation_0-rmse:0.848008	validation_1-rmse:0.827546
# [233]	validation_0-rmse:0.84793	validation_1-rmse:0.827519
# [234]	validation_0-rmse:0.847881	validation_1-rmse:0.827246
# [235]	validation_0-rmse:0.847828	validation_1-rmse:0.827189
# [236]	validation_0-rmse:0.847807	validation_1-rmse:0.827165
# [237]	validation_0-rmse:0.847791	validation_1-rmse:0.827076
# [238]	validation_0-rmse:0.847711	validation_1-rmse:0.827178
# [239]	validation_0-rmse:0.84764	validation_1-rmse:0.827078
# [240]	validation_0-rmse:0.847609	validation_1-rmse:0.827038
# [241]	validation_0-rmse:0.847571	validation_1-rmse:0.827061
# [242]	validation_0-rmse:0.847268	validation_1-rmse:0.826879
# [243]	validation_0-rmse:0.847191	validation_1-rmse:0.826964
# [244]	validation_0-rmse:0.847113	validation_1-rmse:0.826865
# [245]	validation_0-rmse:0.847065	validation_1-rmse:0.826885
# [246]	validation_0-rmse:0.846997	validation_1-rmse:0.826839
# [247]	validation_0-rmse:0.846945	validation_1-rmse:0.826773
# [248]	validation_0-rmse:0.846931	validation_1-rmse:0.826695
# [249]	validation_0-rmse:0.846905	validation_1-rmse:0.826697
# [250]	validation_0-rmse:0.846865	validation_1-rmse:0.826747
# [251]	validation_0-rmse:0.846833	validation_1-rmse:0.826666
# [252]	validation_0-rmse:0.846774	validation_1-rmse:0.826658
# [253]	validation_0-rmse:0.846706	validation_1-rmse:0.8267
# [254]	validation_0-rmse:0.846506	validation_1-rmse:0.826453
# [255]	validation_0-rmse:0.846469	validation_1-rmse:0.826406
# [397]	validation_0-rmse:0.838826	validation_1-rmse:0.821334
# [398]	validation_0-rmse:0.838787	validation_1-rmse:0.821271
# [399]	validation_0-rmse:0.838697	validation_1-rmse:0.821268
# [400]	validation_0-rmse:0.83864	validation_1-rmse:0.821224
# [401]	validation_0-rmse:0.838621	validation_1-rmse:0.821193
# [402]	validation_0-rmse:0.838499	validation_1-rmse:0.82118
# [403]	validation_0-rmse:0.838456	validation_1-rmse:0.821186
# [404]	validation_0-rmse:0.838404	validation_1-rmse:0.821201
# [405]	validation_0-rmse:0.838383	validation_1-rmse:0.821192
# [406]	validation_0-rmse:0.838357	validation_1-rmse:0.821197
# [407]	validation_0-rmse:0.838308	validation_1-rmse:0.821151
# [408]	validation_0-rmse:0.838229	validation_1-rmse:0.821114
# [409]	validation_0-rmse:0.838205	validation_1-rmse:0.821115
# [410]	validation_0-rmse:0.838208	validation_1-rmse:0.821111
# [411]	validation_0-rmse:0.838177	validation_1-rmse:0.821074
# [412]	validation_0-rmse:0.838129	validation_1-rmse:0.820997
# [413]	validation_0-rmse:0.838112	validation_1-rmse:0.820989
# [414]	validation_0-rmse:0.838074	validation_1-rmse:0.820938
# [415]	validation_0-rmse:0.837953	validation_1-rmse:0.82094
# [416]	validation_0-rmse:0.837947	validation_1-rmse:0.820991
# [417]	validation_0-rmse:0.837911	validation_1-rmse:0.82097
# [418]	validation_0-rmse:0.83789	validation_1-rmse:0.820962
# [419]	validation_0-rmse:0.837871	validation_1-rmse:0.820928
# [420]	validation_0-rmse:0.837697	validation_1-rmse:0.820593
# [421]	validation_0-rmse:0.837645	validation_1-rmse:0.820619
# [422]	validation_0-rmse:0.837549	validation_1-rmse:0.820604
# [423]	validation_0-rmse:0.837527	validation_1-rmse:0.820585
# [424]	validation_0-rmse:0.837495	validation_1-rmse:0.82057
# [425]	validation_0-rmse:0.837453	validation_1-rmse:0.820513
# [426]	validation_0-rmse:0.83742	validation_1-rmse:0.820504
# [427]	validation_0-rmse:0.837361	validation_1-rmse:0.820503
# [428]	validation_0-rmse:0.837337	validation_1-rmse:0.82053
# [429]	validation_0-rmse:0.837253	validation_1-rmse:0.820505
# [430]	validation_0-rmse:0.837223	validation_1-rmse:0.820541
# [431]	validation_0-rmse:0.837181	validation_1-rmse:0.820532
# [432]	validation_0-rmse:0.837162	validation_1-rmse:0.82053
# [433]	validation_0-rmse:0.837126	validation_1-rmse:0.820511
# [434]	validation_0-rmse:0.837094	validation_1-rmse:0.820508
# [435]	validation_0-rmse:0.837021	validation_1-rmse:0.820296
# [436]	validation_0-rmse:0.836987	validation_1-rmse:0.82023
# [437]	validation_0-rmse:0.83697	validation_1-rmse:0.82021
# [438]	validation_0-rmse:0.836847	validation_1-rmse:0.820272
# [439]	validation_0-rmse:0.836827	validation_1-rmse:0.820279
# [440]	validation_0-rmse:0.836786	validation_1-rmse:0.820106
# [441]	validation_0-rmse:0.836762	validation_1-rmse:0.820064
# [442]	validation_0-rmse:0.836743	validation_1-rmse:0.820058
# [443]	validation_0-rmse:0.836693	validation_1-rmse:0.820023
# [444]	validation_0-rmse:0.836659	validation_1-rmse:0.819992
# [445]	validation_0-rmse:0.836623	validation_1-rmse:0.819993
# [446]	validation_0-rmse:0.836601	validation_1-rmse:0.81999
# [447]	validation_0-rmse:0.836582	validation_1-rmse:0.819965
# [448]	validation_0-rmse:0.836559	validation_1-rmse:0.820039
# [449]	validation_0-rmse:0.836538	validation_1-rmse:0.820092
# [450]	validation_0-rmse:0.836513	validation_1-rmse:0.820083
# [451]	validation_0-rmse:0.83651	validation_1-rmse:0.820075
# [452]	validation_0-rmse:0.836463	validation_1-rmse:0.819979
# [453]	validation_0-rmse:0.836434	validation_1-rmse:0.819951
# [454]	validation_0-rmse:0.836424	validation_1-rmse:0.819962
# [455]	validation_0-rmse:0.836379	validation_1-rmse:0.819938
# [456]	validation_0-rmse:0.836337	validation_1-rmse:0.81995
# [457]	validation_0-rmse:0.836257	validation_1-rmse:0.819944
# [458]	validation_0-rmse:0.836198	validation_1-rmse:0.819892
# [459]	validation_0-rmse:0.836171	validation_1-rmse:0.819913
# [460]	validation_0-rmse:0.836164	validation_1-rmse:0.819928
# [461]	validation_0-rmse:0.836139	validation_1-rmse:0.819917
# [462]	validation_0-rmse:0.836102	validation_1-rmse:0.819901
# [463]	validation_0-rmse:0.836085	validation_1-rmse:0.819921
# [464]	validation_0-rmse:0.836079	validation_1-rmse:0.819922
# [465]	validation_0-rmse:0.836054	validation_1-rmse:0.819857
# [466]	validation_0-rmse:0.836018	validation_1-rmse:0.819861
# [467]	validation_0-rmse:0.83601	validation_1-rmse:0.819876
# [468]	validation_0-rmse:0.835991	validation_1-rmse:0.819914
# [469]	validation_0-rmse:0.835887	validation_1-rmse:0.819912
# [470]	validation_0-rmse:0.835827	validation_1-rmse:0.819891
# [471]	validation_0-rmse:0.835809	validation_1-rmse:0.819768
# [472]	validation_0-rmse:0.835769	validation_1-rmse:0.819795
# [473]	validation_0-rmse:0.835755	validation_1-rmse:0.8198
# [474]	validation_0-rmse:0.835691	validation_1-rmse:0.81962
# [475]	validation_0-rmse:0.835637	validation_1-rmse:0.819695
# [476]	validation_0-rmse:0.835618	validation_1-rmse:0.819699
# [477]	validation_0-rmse:0.835589	validation_1-rmse:0.819695
# [478]	validation_0-rmse:0.835524	validation_1-rmse:0.819751
# [479]	validation_0-rmse:0.835506	validation_1-rmse:0.819734
# [480]	validation_0-rmse:0.835474	validation_1-rmse:0.819703
# [481]	validation_0-rmse:0.835433	validation_1-rmse:0.819647
# [482]	validation_0-rmse:0.835375	validation_1-rmse:0.81968
# [483]	validation_0-rmse:0.835343	validation_1-rmse:0.820373
# [484]	validation_0-rmse:0.835331	validation_1-rmse:0.82037
# Stopping. Best iteration:
# [474]	validation_0-rmse:0.835691	validation_1-rmse:0.81962
#
# XGB: RMSE train: 0.8388420939445496 RMSE val: 0.8195655941963196
# Wall time: 2h 43min 10s

# %% [markdown]
# 50 min
# XGB: RMSE train: 0.808 RMSE val: 0.809
# 0.91554

# %% [markdown]
# ### CatBoost

# %%
from catboost import CatBoostRegressor

from sklearn.metrics import mean_squared_error

# %%
# Define the CatBoost search space (dynamic parameters)
search_space  = [Integer(6, 10, name='depth'),
                 Integer(1, 10, name='l2_leaf_reg'),
                 Real(0, 1, name='bagging_temperature'),
                 Real(0, 1, name='random_strength')]

#search_space = [           
#                 'depth': Integer(1, 8),
#                 'learning_rate': Real(0.01, 1.0, 'log-uniform'),
#                 'random_strength': Real(1e-9, 10, 'log-uniform'),
#                 'bagging_temperature': Real(0.0, 1.0),
#                 'border_count': Integer(1, 255),
#                 'ctr_border_count': Integer(1, 255),
#                 'l2_leaf_reg': Integer(2, 30),
#                 'scale_pos_weight':Real(0.01, 1.0, 'uniform')}

#                 Real(0.0001, 10000,prior ='log-uniform', name='random_strength'),
#                 Real(0.0001, 10000,prior ='log-uniform', name='bagging_temperature')]
#Real(0.0001, 10000,prior ='log-uniform', name='l2_leaf_reg'),
# Define lgb static parameters
'''static_params = {'eval_metric': 'RMSE',
                 'random_seed': 42,
                 'od_type': 'Iter',
                 'od_wait': 20}     '''
# Out:
# "static_params = {'eval_metric': 'RMSE',\n                 'random_seed': 42,\n                 'od_type': 'Iter',\n                 'od_wait': 20}     "

# %%
# Define a function to minimize - the function should return the value to minimize by gp_minimize function
@skopt.utils.use_named_args(search_space) # This decorator ( @ ) allows the objective function to receive the parameters as keyword arguments
def objective(**dynamic_params): # n_call is used to monitor minimization progress
    
    print(dynamic_params)
    
    #params = {**dynamic_params} # merge the two dictionaries
 
    model = CatBoostRegressor(iterations = 100,
                              **dynamic_params)

    model.fit(X_train, y_train,
              eval_set=(X_val, y_val),
              use_best_model=True,
              verbose=False,
              plot = True)
    
    y_pred_val = model.predict(X_val).clip(0,20)
    rmse_val = np.sqrt(mean_squared_error(y_pred_val, y_val))

    return rmse_val

# %%
# %%time
res_cat = forest_minimize(objective, search_space, n_calls=10, x0=None, callback=[checkpoint_callback], random_state=42)

# %%
dump(res_cat, r'output/HPO_cat_minimization_result.pkl')

# %%
res_cat = load(r'output/HPO_cat_minimization_result.pkl')
print('Best score for cat_minimize', 'rmse_val=', res_cat.fun, 'Best parameters:', res_cat.x)
plot_convergence(res_cat)
plot_objective(res_cat)
plt.show()

# %% [markdown]
# ## Now decrease the learning rate and increase iterations

# %%
def run_catboost(X_train, y_train, X_val, y_val, X_test):
    
    model = CatBoostRegressor()
                              
    model.fit(X_train, y_train,
              eval_set=(X_val, y_val),
              use_best_model=True,
              verbose=True,
              plot = False)
    
    y_pred_train = model.predict(X_train).clip(0,20)
    y_pred_val = model.predict(X_val).clip(0,20)
    y_pred_test = model.predict(X_test).clip(0,20)

    print(f"CatB: RMSE train: {rmse(y_train, y_pred_train)} RMSE val: {rmse(y_val, y_pred_val)}")
    return y_pred_val, y_pred_test, model

# %%
import catboost
catboost.__version__
# Out:
# '0.20.2'

# %%
# %%time
y_pred_val_cat, y_pred_test_cat, cat_model = run_catboost(X_train, y_train, X_val, y_val,  X_test)

# %%
pickle.dump(cat_model, open(r'output/cat_model.pkl', 'wb')) # Save trained model to file
#pickle.dump(y_pred_val_cat, open(r'3. HPO/cat_val.pkl', 'wb')) # save predictions for an ensemble
#pickle.dump(y_pred_test_cat, open(r'3. HPO/cat_test.pkl', 'wb')) # save predictions for an ensemble

submission = pd.DataFrame({'ID': test.index, 'item_cnt_month': y_pred_test_cat})
submission.to_csv(r'output/cat_submission.csv', index=False)

# %% [markdown]
# 22 min
# Train, val, test: 0.784, 0.803, 0.9106

# %% [markdown]
# ### Neural Nets

# %%
# Data preparation for NN
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(X_train)

X_train_ss = scaler.transform(X_train)
X_val_ss   = scaler.transform(X_val)
X_test_ss  = scaler.transform(X_test)

# %%
from sklearn.neural_network import MLPRegressor

def run_nn(X_train_ss, y_train, X_val_ss, y_val, X_test_ss):
    
    model = MLPRegressor(hidden_layer_sizes=(128,64,),
                         verbose = True,
                         early_stopping=True,
                         n_iter_no_change=5,
                         max_iter=2000,
                         tol=1e-3,
                         random_state=42)

    model.fit(X_train, y_train)

    y_pred_train = model.predict(X_train).clip(0,20)
    y_pred_val = model.predict(X_val).clip(0,20)
    y_pred_test = model.predict(X_test).clip(0,20)

    print(f"CatB: RMSE train: {rmse(y_train, y_pred_train)} RMSE val: {rmse(y_val, y_pred_val)}")
    return y_pred_val, y_pred_test, model

# %%
# %%time
y_pred_val_nn, y_pred_test_nn, nn_model = run_nn(X_train, y_train, X_val, y_val,  X_test)

pickle.dump(nn_model, open(r'output/nn_model.pkl', 'wb')) # Save trained model to file
#pickle.dump(y_pred_val_nn, open(r'3. HPO/nn_val.pkl', 'wb')) # save predictions for an ensemble
#pickle.dump(y_pred_test_nn, open(r'3. HPO/nn_test.pkl', 'wb')) # save predictions for an ensemble

submission = pd.DataFrame({'ID': test.index, 'item_cnt_month': y_pred_test_nn})
submission.to_csv(r'output/nn_submission.csv', index=False)
# Out:
# Iteration 1, loss = 69.51718385
# Validation score: -0.262274
# Iteration 2, loss = 1.48691969
# Validation score: -2.475130
# Iteration 3, loss = 0.48201879
# Validation score: 0.388669
# Iteration 4, loss = 0.43356427
# Validation score: 0.403688
# Iteration 5, loss = 0.42681400
# Validation score: 0.402341
# Iteration 6, loss = 0.42044363
# Validation score: 0.411576
# Iteration 7, loss = 0.41775158
# Validation score: 0.379095
# Iteration 8, loss = 0.41550780
# Validation score: 0.418281
# Iteration 9, loss = 0.41341292
# Validation score: 0.426707
# Iteration 10, loss = 0.41097690
# Validation score: 0.424656
# Iteration 11, loss = 0.40968360
# Validation score: 0.429120
# Iteration 12, loss = 0.40822947
# Validation score: 0.435338
# Iteration 13, loss = 0.40751086
# Validation score: 0.439075
# Iteration 14, loss = 0.40677728
# Validation score: 0.416302
# Iteration 15, loss = 0.40613413
# Validation score: 0.413801
# Iteration 16, loss = 0.40508322
# Validation score: 0.435547
# Iteration 17, loss = 0.40423213
# Validation score: 0.437580
# Iteration 18, loss = 0.40418962
# Validation score: 0.435319
# Iteration 19, loss = 0.40322640
# Validation score: 0.420903
# Validation score did not improve more than tol=0.001000 for 5 consecutive epochs. Stopping.
# CatB: RMSE train: 0.8906 RMSE val: 0.86087
# Wall time: 1h 21min 58s

# %% [markdown]
# 1h 22min hidden layers = 128,64, . : 0.891 0.861
